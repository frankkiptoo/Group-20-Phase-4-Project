# %% [markdown]
# # Final Project Submission
# * Student names:
#
# **Frank Kiptoo Ruto**
# **Lilian Ngige**
# **Abdihakim Mohamed**
#
# * Student pace: **Part Time**

# %%
#import relevant libaries
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from matplotlib.pylab import rcParams
from statsmodels.tsa.arima.model import ARIMA
import statsmodels.api as sm
import warnings
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.statespace.sarimax import SARIMAX
from matplotlib.pylab import rcParams

# %%
#loading Data & Explore the Data
df=pd.read_csv("C:/Users/Dell/Desktop/phase 4 project/Group-20-Phase-4-Project/zillow_data.csv")
df.head(10)
# Out:
#    RegionID  RegionName           City State              Metro  \
# 0     84654       60657        Chicago    IL            Chicago
# 1     90668       75070       McKinney    TX  Dallas-Fort Worth
# 2     91982       77494           Katy    TX            Houston
# 3     84616       60614        Chicago    IL            Chicago
# 4     93144       79936        El Paso    TX            El Paso
# 5     91733       77084        Houston    TX            Houston
# 6     61807       10467       New York    NY           New York
# 7     84640       60640        Chicago    IL            Chicago
# 8     91940       77449           Katy    TX            Houston
# 9     97564       94109  San Francisco    CA      San Francisco
#
#       CountyName  SizeRank   1996-04   1996-05   1996-06  ...  2017-07  \
# 0           Cook         1  334200.0  335400.0  336500.0  ...  1005500
# 1         Collin         2  235700.0  236900.0  236700.0  ...   308000
# ...

# %%
print(df.info())
print("Column Names:", df.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14723 entries, 0 to 14722
# Columns: 272 entries, RegionID to 2018-04
# dtypes: float64(219), int64(49), object(4)
# memory usage: 30.6+ MB
# None
# Column Names: Index(['RegionID', 'RegionName', 'City', 'State', 'Metro', 'CountyName',
#        'SizeRank', '1996-04', '1996-05', '1996-06',
#        ...
#        '2017-07', '2017-08', '2017-09', '2017-10', '2017-11', '2017-12',
#        '2018-01', '2018-02', '2018-03', '2018-04'],
#       dtype='object', length=272)

# %%
df.describe()
# Out:
#             RegionID    RegionName      SizeRank       1996-04       1996-05  \
# count   14723.000000  14723.000000  14723.000000  1.368400e+04  1.368400e+04
# mean    81075.010052  48222.348706   7362.000000  1.182991e+05  1.184190e+05
# std     31934.118525  29359.325439   4250.308342  8.600251e+04  8.615567e+04
# min     58196.000000   1001.000000      1.000000  1.130000e+04  1.150000e+04
# 25%     67174.500000  22101.500000   3681.500000  6.880000e+04  6.890000e+04
# 50%     78007.000000  46106.000000   7362.000000  9.950000e+04  9.950000e+04
# 75%     90920.500000  75205.500000  11042.500000  1.432000e+05  1.433000e+05
# max    753844.000000  99901.000000  14723.000000  3.676700e+06  3.704200e+06
#
#             1996-06       1996-07       1996-08       1996-09       1996-10  \
# count  1.368400e+04  1.368400e+04  1.368400e+04  1.368400e+04  1.368400e+04
# mean   1.185374e+05  1.186531e+05  1.187803e+05  1.189275e+05  1.191205e+05
# ...

# %%
df.shape
# Out:
# (14723, 272)

# %%
#Exploratory Data Analysis (EDA)

#Explore the historical trends, seasonality, and price volatility.

# Visualize median home prices over time
plt.figure(figsize=(8, 5))
plt.plot(df['RegionName'], df.iloc[:, 271:])
plt.title('Median Home Prices Over Time')
plt.xlabel('Year-Month')
plt.ylabel('Median Home Price')
plt.show()

# %%
#Creating an Return On Investment column so that the top five regional name/Zip code can be identified

df["%ROI"] = ((df["2018-04"] / df["1996-04"])-1) *  100

df.head(5)
# Out:
#    RegionID  RegionName      City State              Metro CountyName  \
# 0     84654       60657   Chicago    IL            Chicago       Cook
# 1     90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 2     91982       77494      Katy    TX            Houston     Harris
# 3     84616       60614   Chicago    IL            Chicago       Cook
# 4     93144       79936   El Paso    TX            El Paso    El Paso
#
#    SizeRank   1996-04   1996-05   1996-06  ...  2017-09  2017-10  2017-11  \
# 0         1  334200.0  335400.0  336500.0  ...  1007800  1009600  1013300
# 1         2  235700.0  236900.0  236700.0  ...   312500   314100   315000
# 2         3  210400.0  212200.0  212200.0  ...   320200   320400   320800
# 3         4  498100.0  500900.0  503100.0  ...  1287400  1291500  1296600
# 4         5   77300.0   77300.0   77300.0  ...   120000   120300   120300
#
#    2017-12  2018-01  2018-02  2018-03  2018-04        %ROI  ROI price
# ...

# %%
df.describe()
# Out:
#             RegionID    RegionName      SizeRank       1996-04       1996-05  \
# count   14723.000000  14723.000000  14723.000000  1.368400e+04  1.368400e+04
# mean    81075.010052  48222.348706   7362.000000  1.182991e+05  1.184190e+05
# std     31934.118525  29359.325439   4250.308342  8.600251e+04  8.615567e+04
# min     58196.000000   1001.000000      1.000000  1.130000e+04  1.150000e+04
# 25%     67174.500000  22101.500000   3681.500000  6.880000e+04  6.890000e+04
# 50%     78007.000000  46106.000000   7362.000000  9.950000e+04  9.950000e+04
# 75%     90920.500000  75205.500000  11042.500000  1.432000e+05  1.433000e+05
# max    753844.000000  99901.000000  14723.000000  3.676700e+06  3.704200e+06
#
#             1996-06       1996-07       1996-08       1996-09       1996-10  \
# count  1.368400e+04  1.368400e+04  1.368400e+04  1.368400e+04  1.368400e+04
# mean   1.185374e+05  1.186531e+05  1.187803e+05  1.189275e+05  1.191205e+05
# ...

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# RegionID         0
# RegionName       0
# City             0
# State            0
# Metro            0
#               ...
# 2018-02          0
# 2018-03          0
# 2018-04          0
# %ROI          1039
# ROI price     1039
# Length: 274, dtype: int64

# %%
#Filling missing values
df['Metro'].fillna('Unknown', inplace=True)
df.isna().sum()
# Out:
# RegionID         0
# RegionName       0
# City             0
# State            0
# Metro            0
#               ...
# 2018-02          0
# 2018-03          0
# 2018-04          0
# %ROI          1039
# ROI price     1039
# Length: 274, dtype: int64

# %%
#Filling missing values in Roi with mean
df['%ROI'].fillna(df['%ROI'].mean(), inplace=True)
df['ROI price'].fillna(df['ROI price'].mean(), inplace=True)
df.isna().sum()
# Out:
# RegionID      0
# RegionName    0
# City          0
# State         0
# Metro         0
#              ..
# 2018-02       0
# 2018-03       0
# 2018-04       0
# %ROI          0
# ROI price     0
# Length: 274, dtype: int64
